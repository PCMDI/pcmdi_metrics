# %%
import xarray as xr
import os
import numpy as np
import cftime

bdir = "/global/cfs/projectdirs/m2637/star-esdm_nclimgrid_conus/"
scen = "ssp245"
odir = "/pscratch/sd/j/jsgoodni/star_scratch/"

os.makedirs(odir, exist_ok=True)

for variable in ["pr", "tasmax", "tasmin"]:
    print(f"[Working on {variable}]") 
    ovdir = f"{odir}{variable}"
    os.makedirs(ovdir, exist_ok=True)
    
    vdir = f"{bdir}/{variable}/{scen}/"

    files = [file for file in os.listdir(vdir) if file.startswith('downscaled')]
    models = np.unique([f.split('.')[1] for f in files])
    chunks = {"time": 365, "latitude": -1, "longitude": -1}

    for model in models[0:1]: 
        print(model)
        mfils = np.sort([f"{vdir}{file}" for file in files if model in file])[0:7]
        arr = []

        ds = xr.open_mfdataset(mfils, decode_times = False)
        units = ds.time.attrs["units"].replace(","," ")
        cal   = ds.time.attrs.get('calendar', 'standard')
        if cal == '365-day': 
            cal = '365_day'
        times = cftime.num2date(ds.time.values, units, cal)
        ds = ds.assign_coords(time = ("time", np.array(times, dtype = 'object')))
        # ds = ds.rechunk()
# Out:
# [Working on pr]
# ACCESS-CM2
# <frozen importlib._bootstrap>:241: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility. Expected 16 from C header, got 96 from PyObject
# [Working on tasmax]
# ACCESS-CM2
# [Working on tasmin]
# ACCESS-CM2

# %%
from dask.distributed import Client
client = Client()

# %%
ds.mean(dim = "time")
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:    (latitude: 596, longitude: 1385)
# Coordinates:
#   * latitude   (latitude) float64 5kB 24.56 24.6 24.65 ... 49.27 49.31 49.35
#   * longitude  (longitude) float64 11kB 235.3 235.4 235.4 ... 292.9 292.9 293.0
# Data variables:
#     tasmin     (latitude, longitude) float64 7MB dask.array<chunksize=(8, 16), meta=np.ndarray>

# %%
ds.chunks
# Out:
# Frozen({'time': (365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365, 365), 'latitude': (8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 4), 'longitude': (16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 9)})
